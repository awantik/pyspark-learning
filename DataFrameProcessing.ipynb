# %%
from pyspark.sql import Row
df = spark.createDataFrame([ Row(name='a',age=55), Row(name='b',age=66), Row(name='c',age=77) ])

# %%
df.withColumn('new_col',df.age + 5).show()

# %%
df2 = spark.createDataFrame([ Row(loc='Bangalore'), Row(loc='Chennai'), Row(loc='Mumbai') ])

# %%
df2.loc

# %%
df.withColumn('n',df2.loc.)
