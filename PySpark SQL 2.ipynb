# %%
df = spark.read.csv('/FileStore/tables/tms6y3m11489506600338/Predictor_variables_raw.csv',header=True,inferSchema=True)

# %%
from pyspark.sql import Row
rdd = sc.parallelize([Row(name='a', age=99, height=100), Row(name='b',age=50,height=100), Row(name='b',age=50,height=78)])

# %%
df1 = rdd.toDF()

# %%
df1.show()

# %%
#dropDuplicates is not in-memory operation - it will not change contents of df1
df1.dropDuplicates().show()

# %%
df1.show()

# %%
rdd.collect()

# %%
df1.show()

# %%
rdd = sc.parallelize([Row(name='a', age=50, height=100), Row(name='b',age=51,height=100), Row(name='b',age=50,height=78)])

# %%
rdd.toDF().dropDuplicates(['age']).show()

# %%
rdd = sc.parallelize([Row(name='a', age=50, height=100), Row(name='b',age=None, height=100), Row(name='b',age=50,height=78)])

# %%
df1 = rdd.toDF()

# %%
df1.dropna().show()

# %%
df_data = spark.read.csv('/FileStore/tables/c86o9lhs1489507726768/data_num-9d9e3.csv')

# %%
df_data.dropna().show()

# %%
df.show()

# %%
df =df.drop('skuid')

# %%
df.show()

# %%
help(df.na)

# %%
rdd = sc.parallelize([Row(name='a', age=50, height=100), Row(name='b',age=None, height=100), Row(name=None,age=50,height=78)])

# %%
rdd.toDF().show()

# %%
rdd.toDF().na.fill({'age':0, 'name':'Junk'}).show()

# %%
tdf = rdd.toDF()

# %%
tdf.show()

# %%
tdf.filter("age > 0").collect()

# %%
tdf.show()

# %%
def f(p):
  if p.age > 0:
    print p.name 
  
tdf.foreach(f)

# %%
def f(x,y):
  print x 
  print 'Awantik'
  return x
rdd.reduce(f)

# %%
rdd.collect()

# %%
df.

# %%
def f(r):
  if r.sales > 300:
    print r.sku
df.foreach(f)

# %%
sales = spark.read.csv('/FileStore/tables/esisj2031489547677702/Predictor_variables_raw.csv', header=True, inferSchema=True)

# %%
col = sales.select('sales')

# %%
help(col)

# %%
sales.
