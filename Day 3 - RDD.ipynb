# %%
rdd = sc.parallelize(range(500))

# %%
rdd1, rdd2 = rdd.randomSplit((2,8))

# %%
rdd1.count()

# %%
rdd2.count()

# %%
l = [2,1,1,1,212,1,23,5,6,7,75]
m = [45,6,3,2,9,1,1,31,33,6,22]
d = zip(l,m)

# %%
rdd = sc.parallelize(d)

# %%
rdd.collect()

# %%
rdd.sortBy(lambda x: x[1],ascending=False).collect()

# %%
rdd.toDebugString()

# %%
rdd.count()

# %%
def f(d):
  print d
  return d+2

l = [1,2,3,4,5]
rdd = sc.parallelize(l)
rdd.map(f).collect()

# %%
from pyspark.sql import SparkSession

# %%
ss = SparkSession.builder.master("local")

# %%
s = ss.getOrCreate()

# %%
t = s.newSession()

# %%
rdd = t.sparkContext.parallelize(range(10))

# %%
def f(data):
  print data
  return data
rdd.map(f).count()
