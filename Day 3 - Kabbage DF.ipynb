# %%
from pyspark.sql import Row

# %%
row1 = Row(name="Awi", age=10)

# %%
row1

# %%
row1.name

# %%
Employee = Row("name","location")

# %%
Employee("Awi","Bangalore")

# %%
row1.asDict()

# %%
Row(name="A", val=Row(sub='Science',loc='Mumbai'))

# %%
# Creation of dataframes
spark.createDataFrame([('Alice',1,22),('Byom',3,66)],['name','age','salary']).show()

# %%
db = [{'name':'Akbar','loc':'delhi'},{ 'name' :'sikandar', 'loc':'lucknow'}]

# %%
spark.createDataFrame(db).show()

# %%
l = [('Awi',1),('Bwi',2)]

# %%
rdd = sc.parallelize(l)

# %%
Person = Row("name","age")

# %%
p1 = rdd.map( lambda x: Person(*x))

# %%
df = spark.createDataFrame(p1)

# %%
df.show()

# %%
df.select('name').show()

# %%
import pandas as pd

# %%
pdf = df.toPandas()

# %%
spark.createDataFrame(pdf).show()

# %%
data = spark.read.csv('/FileStore/tables/vc9z36401490339549155/database.csv',inferSchema=True, header=True)

# %%
display(data)

# %%
data.printSchema()

# %%
data.count()

# %%
data.columns

# %%
display(data.select('Relationship').distinct())
